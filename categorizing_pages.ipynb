# %% [markdown]
# <a href="https://colab.research.google.com/github/ratmcu/wiki_ner/blob/master/categorizing_pages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wget
import os
import wget
import logging
import pickle
import ast
import pandas as pd
import numpy as np
import urllib
from bs4 import BeautifulSoup
logger = logging.getLogger()
logger.setLevel(logging.INFO)
# !rm 'Living_people.pkl'
wget.download('https://github.com/ratmcu/wiki_ner/blob/master/Living_people.pkl?raw=true')
# Out:
# Collecting wget
#   Downloading https://files.pythonhosted.org/packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9681 sha256=15a8973e22b4ce807c518f0e57417ab92e8c7b2d7b8fc564a2a07221cf4e000e
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# rm: cannot remove 'Living_people.pkl': No such file or directory
# 'Living_people.pkl'

# %%
def add_wiki_prefix(func):
    def wrapper(url):
        url = 'https://en.wikipedia.org' + url
        return func(url)
    return wrapper

@add_wiki_prefix
def get_category_list(url):
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page, 'html.parser')
    catlink_box = soup.find('div', attrs={'class': 'mw-normal-catlinks'}) # or infobox biography vcard
    return [ li.text for li in catlink_box.find_all('li')]

def create_category_table(url_list):
    category_df =  pd.DataFrame()
    for i, link in enumerate(url_list):
        print(i, link)
    #     cats = [category for category in get_category_list(str(link))]
        cats = get_category_list(str(link))
        df_cats =  pd.DataFrame(np.ones((1,len(cats)), dtype=np.int64), columns=cats)
        category_df = category_df.append(df_cats)
    return category_df

# %%
with open('Living_people.pkl', 'rb') as f:
    js = pickle.load(f)
# js = json.load(js)    
links_js = ast.literal_eval(js)
print(links_js[0])
# category_df =  pd.DataFrame()
# for i, link in enumerate(links_js):
#     print(i, link)
# #     cats = [category for category in get_category_list(str(link))]
#     cats = get_category_list(str(link))
#     df_cats =  pd.DataFrame(np.ones((1,len(cats)), dtype=np.int64), columns=cats)
#     category_df = category_df.append(df_cats)
#     if i == 100:
#         break
import time
start_time = time.perf_counter()
df = create_category_table(links_js[:100])
end_time = time.perf_counter()      # 2
run_time = end_time - start_time 
print(run_time)
df
# Out:
# /wiki/Judge_Edward_Aaron
# 0 /wiki/Judge_Edward_Aaron
# 1 /wiki/Mohamed_Jamshid_Abadi
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# 2 /wiki/Abbas_Sami%27i
# 3 /wiki/Abdul_Rashid_Abbasi
# 4 /wiki/Ibrahim_Abdel_Hamid
# 5 /wiki/Mohamed_Abdel-El
# 6 /wiki/Ibrahim_Abdrabbou
# 7 /wiki/Qazi_Abdul_Waheed
# 8 /wiki/Abdulganiyu_Abdulrasaq
# 9 /wiki/Ben_Sa%C3%AFd_Abdallah
# 10 /wiki/Hiroshi_Abe_(war_criminal)
# 11 /wiki/Osamu_Abe_(rower)
# 12 /wiki/Maria_do_Carmo_Abecassis
# 13 /wiki/Youssef_Abou_Ouf
# 14 /wiki/Ahmed_Abou-Shadi
# 15 /wiki/Ahmad_Shah_Abouwi
# 16 /wiki/Andrei_Abraham
# 17 /wiki/Faghme_Abrahams
# 18 /wiki/Elisabeta_Abrudeanu
# 19 /wiki/Anton%C3%ADn_Absolon
# 20 /wiki/Milada_Absolonov%C3%A1
# 21 /wiki/Rauf_Abu_Al-Seoud
# 22 /wiki/Aziz_al-Abub
# 23 /wiki/Roqia_Abubakr
# 24 /wiki/A._R._A._M._Abubucker
# 25 /wiki/Perla_Ach%C3%A1val
# 26 /wiki/Juli%C3%A1n_Acosta
# 27 /wiki/Geormbeeyi_Adali-Mortty
# 28 /wiki/Dimitrios_Adamou
# 29 /wiki/Don_Adams_(boxer)
# 30 /wiki/Jimmy_Adamson_(Scottish_footballer)
# 31 /wiki/Tommy_Adamson
# 32 /wiki/Aden_Isaq_Ahmed
# 33 /wiki/Antonio_Adipe
# 34 /wiki/Gharib_Afifi
# 35 /wiki/Faiz_Aftab
# 36 /wiki/Dante_Agostini_(canoer)
# 37 /wiki/Manuel_Ag%C3%BCero
# 38 /wiki/Dario_Aguilar
# 39 /wiki/Jorge_Aguirre_(athlete)
# 40 /wiki/Jim_Aherne
# 41 /wiki/Jahan_Ahir
# 42 /wiki/Abbas_Ahmad
# 43 /wiki/Qari_Ahmadullah
# 44 /wiki/Hamid_Ahmed
# 45 /wiki/Iftikhar_Ahmed_(Kalat_cricketer)
# 46 /wiki/Nasim_Ahmed_(cricketer)
# 47 /wiki/Zia_Ahmed
# 48 /wiki/Guillermo_Ahrens
# 49 /wiki/Antonio_Ahumada
# 50 /wiki/Mariam_Mint_Ahmed_Aicha
# 51 /wiki/Juan_%C3%81ngel_Aichino
# 52 /wiki/Toyoji_Aihara
# 53 /wiki/Georges_Ailleres
# 54 /wiki/Ambrosio_Aimar
# 55 /wiki/Enrico_Airoldi
# 56 /wiki/Remo_Airoldi
# 57 /wiki/Ronald_Aitken
# 58 /wiki/Apparanda_Aiyappa
# 59 /wiki/Yumeko_Aizome
# 60 /wiki/Raif_Akbulut
# 61 /wiki/George_Akers_(footballer)
# 62 /wiki/Ernest_Ako
# 63 /wiki/Ausonio_Alacevich
# 64 /wiki/Mart%C3%ADn_Alarc%C3%B3n_(athlete)
# 65 /wiki/Ruperto_Alaura
# 66 /wiki/Julio_Alba
# 67 /wiki/Giuseppe_Albani_(footballer)
# 68 /wiki/Ilse_Albert
# 69 /wiki/Hermenegildo_Alberti
# 70 /wiki/Justo_Albornoz
# 71 /wiki/Luis_Albornoz
# 72 /wiki/Hans_Albrecht
# 73 /wiki/Pierre_Albrecht
# 74 /wiki/Lothar_Albrich
# 75 /wiki/Manole_Aldescu
# 76 /wiki/John_Aldred_(sound_engineer)
# 77 /wiki/Charlie_Aldrich
# 78 /wiki/Guido_Aleati
# 79 /wiki/Carlos_Alegre
# 80 /wiki/Lev_Alekseyev
# 81 /wiki/Pierre_d%27Alen%C3%A7on
# 82 /wiki/Geoffrey_Alexander
# 83 /wiki/George_Alexander_(Canadian_football)
# 84 /wiki/James_R._Alexander
# 85 /wiki/Sergio_Alfafara
# 86 /wiki/Paul_Alford
# 87 /wiki/Hussein_El-Alfy
# 88 /wiki/Luciano_Alghisi
# 89 /wiki/Ahmed_Khalaf_Ali
# 90 /wiki/Dina_Ali_Lasloom
# 91 /wiki/Gibreel_Ali
# 92 /wiki/Hamza_Ali_(footballer)
# 93 /wiki/Majeed_Ali
# 94 /wiki/Mubarak_Ali_(cricketer)
# 95 /wiki/Syed_Osman_Ali
# 96 /wiki/Turab_Ali_(cricketer)
# 97 /wiki/Wazir_Ali_(cyclist)
# 98 /wiki/Juan_Alighieri
# 99 /wiki/Ibrahim_Aliyu
# 19.273384465999996
#     1909 births  ...  Wrestlers at the 1952 Summer Olympics
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           1.0  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# ..          ...  ...                                    ...
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
#
# [100 rows x 432 columns]

# %%
import multiprocessing
import os
# split a list into evenly sized chunks
# !pip install wget
import wget
import logging
import pickle
import ast
import pandas as pd
import numpy as np
import urllib
from bs4 import BeautifulSoup
# !rm 'Living_people.pkl'
wget.download('https://github.com/ratmcu/wiki_ner/blob/master/Living_people.pkl?raw=true')

def chunks(l, n):
    return [l[i:i+n] for i in range(0, len(l), n)]


def do_job(job_id, data_slice, queue):
    queue.put(create_category_table(data_slice))
        

def dispatch_jobs(data, job_number):
    category_data_frame =  pd.DataFrame()
    total = len(data)
    chunk_size = total // job_number
    slice = chunks(data, chunk_size)
    jobs = []
    queue = multiprocessing.Queue(1000)
    for i, s in enumerate(slice):
        j = multiprocessing.Process(target=do_job, args=(i, s, queue))
        jobs.append(j)
    for j in jobs:
        j.start()
    running = any(p.is_alive() for p in jobs)
    while running:
#         while not queue.empty():
#             category_data_frame = category_data_frame.append(queue.get())
        category_data_frame = category_data_frame.append(queue.get(block=True))
        running = any(p.is_alive() for p in jobs)
    for j in jobs:
        j.join()
    return category_data_frame

data = links_js[:100]
start_time = time.perf_counter()
category_data_frame = dispatch_jobs(data, os.cpu_count())
end_time = time.perf_counter()      # 2
run_time = end_time - start_time 
print(run_time)
category_data_frame
# Out:
# 0 /wiki/Judge_Edward_Aaron
# 0 /wiki/Mariam_Mint_Ahmed_Aicha
# 1 /wiki/Juan_%C3%81ngel_Aichino
# 1 /wiki/Mohamed_Jamshid_Abadi
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# 2 /wiki/Toyoji_Aihara
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# 2 /wiki/Abbas_Sami%27i
# 3 /wiki/Georges_Ailleres
# 3 /wiki/Abdul_Rashid_Abbasi
# 4 /wiki/Ambrosio_Aimar
# 4 /wiki/Ibrahim_Abdel_Hamid
# 5 /wiki/Enrico_Airoldi
# 5 /wiki/Mohamed_Abdel-El
# 6 /wiki/Remo_Airoldi
# 6 /wiki/Ibrahim_Abdrabbou
# 7 /wiki/Ronald_Aitken
# 7 /wiki/Qazi_Abdul_Waheed
# 8 /wiki/Apparanda_Aiyappa
# 8 /wiki/Abdulganiyu_Abdulrasaq
# 9 /wiki/Yumeko_Aizome
# 9 /wiki/Ben_Sa%C3%AFd_Abdallah
# 10 /wiki/Raif_Akbulut
# 10 /wiki/Hiroshi_Abe_(war_criminal)
# 11 /wiki/George_Akers_(footballer)
# 11 /wiki/Osamu_Abe_(rower)
# 12 /wiki/Ernest_Ako
# 12 /wiki/Maria_do_Carmo_Abecassis
# 13 /wiki/Ausonio_Alacevich
# 13 /wiki/Youssef_Abou_Ouf
# 14 /wiki/Mart%C3%ADn_Alarc%C3%B3n_(athlete)
# 14 /wiki/Ahmed_Abou-Shadi
# 15 /wiki/Ruperto_Alaura
# 15 /wiki/Ahmad_Shah_Abouwi
# 16 /wiki/Julio_Alba
# 17 /wiki/Giuseppe_Albani_(footballer)
# 16 /wiki/Andrei_Abraham
# 17 /wiki/Faghme_Abrahams
# 18 /wiki/Ilse_Albert
# 18 /wiki/Elisabeta_Abrudeanu
# 19 /wiki/Hermenegildo_Alberti
# 19 /wiki/Anton%C3%ADn_Absolon
# 20 /wiki/Justo_Albornoz
# 20 /wiki/Milada_Absolonov%C3%A1
# 21 /wiki/Luis_Albornoz
# 21 /wiki/Rauf_Abu_Al-Seoud
# 22 /wiki/Hans_Albrecht
# 22 /wiki/Aziz_al-Abub
# 23 /wiki/Pierre_Albrecht
# 23 /wiki/Roqia_Abubakr
# 24 /wiki/Lothar_Albrich
# 24 /wiki/A._R._A._M._Abubucker
# 25 /wiki/Manole_Aldescu
# 25 /wiki/Perla_Ach%C3%A1val
# 26 /wiki/John_Aldred_(sound_engineer)
# 26 /wiki/Juli%C3%A1n_Acosta
# 27 /wiki/Charlie_Aldrich
# 27 /wiki/Geormbeeyi_Adali-Mortty
# 28 /wiki/Guido_Aleati
# 28 /wiki/Dimitrios_Adamou
# 29 /wiki/Carlos_Alegre
# 29 /wiki/Don_Adams_(boxer)
# 30 /wiki/Lev_Alekseyev
# 30 /wiki/Jimmy_Adamson_(Scottish_footballer)
# 31 /wiki/Pierre_d%27Alen%C3%A7on
# 31 /wiki/Tommy_Adamson
# 32 /wiki/Geoffrey_Alexander
# 32 /wiki/Aden_Isaq_Ahmed
# 33 /wiki/George_Alexander_(Canadian_football)
# 33 /wiki/Antonio_Adipe
# 34 /wiki/James_R._Alexander
# 34 /wiki/Gharib_Afifi
# 35 /wiki/Sergio_Alfafara
# 35 /wiki/Faiz_Aftab
# 36 /wiki/Paul_Alford
# 36 /wiki/Dante_Agostini_(canoer)
# 37 /wiki/Hussein_El-Alfy
# 37 /wiki/Manuel_Ag%C3%BCero
# 38 /wiki/Luciano_Alghisi
# 38 /wiki/Dario_Aguilar
# 39 /wiki/Ahmed_Khalaf_Ali
# 39 /wiki/Jorge_Aguirre_(athlete)
# 40 /wiki/Dina_Ali_Lasloom
# 40 /wiki/Jim_Aherne
# 41 /wiki/Jahan_Ahir
# 41 /wiki/Gibreel_Ali
# 42 /wiki/Abbas_Ahmad
# 42 /wiki/Hamza_Ali_(footballer)
# 43 /wiki/Qari_Ahmadullah
# 43 /wiki/Majeed_Ali
# 44 /wiki/Hamid_Ahmed
# 44 /wiki/Mubarak_Ali_(cricketer)
# 45 /wiki/Iftikhar_Ahmed_(Kalat_cricketer)
# 45 /wiki/Syed_Osman_Ali
# 46 /wiki/Nasim_Ahmed_(cricketer)
# 46 /wiki/Turab_Ali_(cricketer)
# 47 /wiki/Zia_Ahmed
# 47 /wiki/Wazir_Ali_(cyclist)
# 48 /wiki/Guillermo_Ahrens
# 48 /wiki/Juan_Alighieri
# 49 /wiki/Antonio_Ahumada
# 49 /wiki/Ibrahim_Aliyu
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# 5.626944760000015
#     1909 births  ...  Wrestlers at the 1952 Summer Olympics
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           1.0  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# ..          ...  ...                                    ...
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
# 0           NaN  ...                                    NaN
#
# [100 rows x 432 columns]
